# %%
import numpy
import pandas as pds
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns

# %%
# set width of bar
barWidth = 0.07

# set height of bar

# Topt__25 = [3.594463124, 3.247372177, 9.680717078, 2.965028649, 4.47920275, 6.384661466, 3.70105621]
# Topt__20 = [4.305277564, 3.921777812, 13.10811766, 3.655098964, 5.923257414, 8.836787752, 4.073545461]
# Topt__15 = [5.53916738, 5.171361761, 17.19165153, 4.62872195, 8.108338209, 11.67322616, 4.858141062]
# Topt__10 = [7.623792023, 7.153367383, 20.72941833, 6.21235779, 10.58911524, 14.31695685, 6.350792607]
# Topt__5 = [10.44449401, 10.22086447, 21.18269842, 8.907689562, 12.44147086, 16.20297557, 9.07995115]
# Topt = [13.64148888, 13.56385731, 19.87152823, 12.47762096, 13.60686395, 17.00315612, 15.5083795]
# Topt_5 = [16.44958006, 15.69930298, 17.57014166, 15.27189669, 13.97514309, 16.84727233, 24.26114443]
# Topt_10 = [18.30843228, 16.49717494, 14.83263352, 16.62845242, 13.66328966, 15.89517285, 28.37171965]
# Topt_15 = [18.84397946, 16.12034444, 12.05982483, 16.60560783, 12.87877257, 14.46978312, 28.79336047]
# Topt_20 = [18.19192784, 14.95548835, 9.691593917, 15.68625235, 11.82468621, 12.894175, 26.63069446]
# Topt_25 = [16.74996862, 13.38064628, 7.976113603, 14.13957832, 10.69207949, 11.36443425, 22.80946603]

file =('/Users/shubhamjamdade/Desktop/Paper O2_He/Final Data Processing/GCMC_Data/All Data.xlsx')

Data = pds.read_excel(file, 'Vicnity_Top_10', nrows=11)

Topt__25 = numpy.array(Data['Minus25']).tolist()
Topt__20 = numpy.array(Data['Minus20']).tolist()
Topt__15 = numpy.array(Data['Minus15']).tolist()
Topt__10 = numpy.array(Data['Minus10']).tolist()
Topt__5 = numpy.array(Data['Minus5']).tolist()
Topt = numpy.array(Data['Topt']).tolist()
Topt_5 = numpy.array(Data['plus5']).tolist()
Topt_10 = numpy.array(Data['plus10']).tolist()
Topt_15 = numpy.array(Data['plus15']).tolist()
Topt_20 = numpy.array(Data['plus20']).tolist()
Topt_25 = numpy.array(Data['plus25']).tolist()

print(Topt__25)

# Set position of bar on X axis
br1 = numpy.arange(len(Topt__25))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]
br5 = [x + barWidth for x in br4]
br6 = [x + barWidth for x in br5]
br7 = [x + barWidth for x in br6]
br8 = [x + barWidth for x in br7]
br9 = [x + barWidth for x in br8]
br10 = [x + barWidth for x in br9]
br11 = [x + barWidth for x in br10]

fig, ax = plt.subplots(figsize=(15, 8))

# Make the plot
ax.bar(br1, Topt__25, color ='tab:blue', width = barWidth,
        edgecolor ='black', label ='$\ T_{opt} -25$')
ax.bar(br2,Topt__20, color ='tab:orange', width = barWidth,
        edgecolor ='black', label ='$\ T_{opt} -20$')
ax.bar(br3, Topt__15, color ='tab:green', width = barWidth,
        edgecolor ='black', label ='$\ T_{opt} -15$')
ax.bar(br4, Topt__10, color ='tab:red', width = barWidth,
        edgecolor ='black', label ='$\ T_{opt} -10$')
ax.bar(br5, Topt__5, color ='tab:purple', width = barWidth,
        edgecolor ='black', label ='$\ T_{opt} -5$')
ax.bar(br6, Topt, color ='tab:brown', width = barWidth,
        edgecolor ='black', label ='$\ T_{opt}$')
ax.bar(br7, Topt_5, color ='tab:pink', width = barWidth,
        edgecolor ='black', label ='$\ T_{opt} +5$')
ax.bar(br8, Topt_10, color ='tab:gray', width = barWidth,
        edgecolor ='black', label ='$\ T_{opt} +10$')
ax.bar(br9, Topt_15, color ='tab:olive', width = barWidth,
        edgecolor ='black', label ='$\ T_{opt} +15$')
ax.bar(br10, Topt_20, color ='tab:cyan', width = barWidth,
        edgecolor ='black', label ='$\ T_{opt} +20$')
ax.bar(br11, Topt_25, color ='yellow', width = barWidth,
        edgecolor ='black', label ='$\ T_{opt} +25$')


ax.set_xlabel('MOF Structure Code', fontsize = 16)
ax.set_ylabel('$\Delta N_{O_{2}} (mol/kg)$', fontsize = 16)
ax.set_yticklabels(['0', '5', '10', '15', '20', '25'], fontsize = 16)
#ax.set_title('Topt Uncertainty')
ax.set_xticks([r + 5*barWidth for r in range(len(Topt))])
ax.set_xticklabels(['ODIXEG', 'HAFTOZ', 'XEBHOC', 'LURGEL', 'XAWVUN', 'ANUGIA', 'JEJWOL', 'BICDAU', 'HIGRIA', 'NEDWIE'], fontweight ='bold', fontsize = 14)


ax.legend()
ax.legend(bbox_to_anchor=(1.0, 1.0))

plt.savefig("Bar_Plot.pdf")
#plt.show()
# Out:
# [6.832712332200003, 9.6807170782, 3.2775147573999988, 6.384661466000004, 3.701056209699999, 3.594463123499999, 4.479202750100004, 3.2473721765000008, 2.9650286485000024, 3.733213042500001, nan]

# %%
file =('/Users/shubhamjamdade/Desktop/Paper O2_He/Final Data Processing/GCMC_Data/All Data.xlsx')

Data = pds.read_excel(file, 'Isotherm Top 10 MOFs')

Pressure = numpy.array(Data['Pressure'])

ODIXEG = numpy.array(Data['ODIXEG'])
HAFTOZ = numpy.array(Data['HAFTOZ'])
XEBHOC = numpy.array(Data['XEBHOC'])
LURGEL = numpy.array(Data['LURGEL'])
XAWVUN = numpy.array(Data['XAWVUN'])
ANUGIA = numpy.array(Data['ANUGIA'])
JEJWOL = numpy.array(Data['JEJWOL'])
BICDAU = numpy.array(Data['BICDAU'])
HIGRIA = numpy.array(Data['HIGRIA'])
NEDWIE = numpy.array(Data['NEDWIE'])

# %%
list = [ODIXEG, HAFTOZ, XEBHOC, LURGEL, XAWVUN, ANUGIA, JEJWOL, BICDAU, HIGRIA, NEDWIE] 
for i in list:
    
            plt.scatter(Pressure, i)
            plt.plot(Pressure, i)
           
            plt.xlabel("Pressure (Bar)", fontsize=16)

            plt.ylabel('$O_{2}$ Uptake (mol/kg)', fontsize=16)

            plt.xticks(fontsize=14) 

            plt.yticks(fontsize=14)
            plt.yticks(numpy.arange(0, 35, step=5))
            

plt.legend(['ODIXEG', 'HAFTOZ', 'XEBHOC', 'LURGEL', 'XAWVUN', 'ANUGIA', 'JEJWOL', 'BICDAU', 'HIGRIA', 'NEDWIE'], bbox_to_anchor = (1.0, 1.05), fontsize=14 )

plt.title('$ O_2 $' + ' Adsorption Isotherms at 298 K', fontsize=16)
# Out:
# Text(0.5, 1.0, '$ O_2 $ Adsorption Isotherms at 298 K')

# %%
file =('/Users/shubhamjamdade/Desktop/Paper O2_He/Final Data Processing/GCMC_Data/All Data.xlsx')

Data = pds.read_excel(file, 'Isotherm Top 10 MOFs')

Pressure = numpy.array(Data['PRESSURE'])

ODIXEG = numpy.array(Data['ODIXEG@151 K'])
HAFTOZ = numpy.array(Data['HAFTOZ@147 K'])
XEBHOC = numpy.array(Data['XEBHOC@126 K'])
LURGEL = numpy.array(Data['LURGEL@153 K'])
XAWVUN = numpy.array(Data['XAWVUN@125 K'])
ANUGIA = numpy.array(Data['ANUGIA@140 K'])
JEJWOL = numpy.array(Data['JEJWOL@148 K'])
BICDAU = numpy.array(Data['BICDAU@141 K'])
HIGRIA = numpy.array(Data['HIGRIA@139 K'])
NEDWIE = numpy.array(Data['NEDWIE@151 K'])

# %%
list = [ODIXEG, HAFTOZ, XEBHOC, LURGEL, XAWVUN, ANUGIA, JEJWOL, BICDAU, HIGRIA, NEDWIE] 
for i in list:
    
            plt.scatter(Pressure, i)
            plt.plot(Pressure, i)
           
            plt.xlabel("Pressure (Bar)", fontsize=16)

            plt.ylabel('$O_{2}$ Uptake (mol/kg)', fontsize=16)

            plt.xticks(fontsize=14) 

            plt.yticks(fontsize=14)
            plt.yticks(numpy.arange(5, 60, step=10))
            

plt.legend(['ODIXEG @151 K' , 'HAFTOZ @147 K' ,'XEBHOC @126 K', 'LURGEL @153 K', 'XAWVUN @125 K', 'ANUGIA @140 K', 'JEJWOL @148 K','BICDAU @141 K', 'HIGRIA @139 K','NEDWIE @151 K'], bbox_to_anchor = (1.0, 1.0), fontsize=12 )
#plt.legend(['ODIXEG' , 'HAFTOZ' ,'SUKYIH', 'FUNBOG', 'KEFBEE', 'NUTQAV','YUGLES', 'FUNBEW','OJICUG', 'FUNCEX','LURGEL'], bbox_to_anchor = (1.0, 1.05), fontsize=14 )

plt.title('$ O_2 $' + ' Adsorption Isotherms', fontsize=16)
# Out:
# Text(0.5, 1.0, '$ O_2 $ Adsorption Isotherms')

# %%
#file =('/Users/shubhamjamdade/Desktop/Paper O2_He/New - Data Processing/Delta_H_top_10/Finding Topt.xlsx')
file =('/Users/shubhamjamdade/Desktop/Paper O2_He/Final Data Processing/GCMC_Data/All Data.xlsx')

Data = pds.read_excel(file, 'Regression_finding_Topt_10')


Temperature = numpy.array(Data['Temperature'])
ODIXEG = numpy.array(Data['ODIXEG'])
HAFTOZ = numpy.array(Data['HAFTOZ'])
XEBHOC = numpy.array(Data['XEBHOC'])
LURGEL = numpy.array(Data['LURGEL'])
XAWVUN = numpy.array(Data['XAWVUN'])
ANUGIA = numpy.array(Data['ANUGIA'])
JEJWOL = numpy.array(Data['JEJWOL'])
BICDAU = numpy.array(Data['BICDAU'])
HIGRIA = numpy.array(Data['HIGRIA'])
NEDWIE = numpy.array(Data['NEDWIE'])

Topt = numpy.array(Data['T_opt(10.22R)'])
Delta_H = numpy.array(Data['Delta_H_O2'])

#CCDC_ref_code = numpy.array(Data['CCDC ref code'])
CCDC_ref_code = ['ODIXEG', 'HAFTOZ', 'XEBHOC', 'LURGEL', 'XAWVUN', 'ANUGIA', 'JEJWOL', 'BICDAU', 'HIGRIA', 'NEDWIE']
Topt_150K = numpy.array(Data['Topt_150K'].head(10))
Topt_regression = numpy.array(Data['Topt_regression'].head(10))
Topt_actual = numpy.array(Data['Topt_actual'].head(10))

# %%
list = [ODIXEG, HAFTOZ, XEBHOC, LURGEL, XAWVUN, ANUGIA, JEJWOL, BICDAU, HIGRIA, NEDWIE] 
for i in list:
    
            plt.scatter(Temperature, i)
            plt.plot(Temperature, i)
           

            
plt.scatter(Topt, Delta_H)
plt.plot(Topt, Delta_H)
plt.xlabel("Temperature (K)", fontsize=16)

plt.ylabel('Heat of adsorption (KJ/mol)', fontsize=16)

plt.xticks(fontsize=14) 

plt.yticks(fontsize=14)

plt.xticks(numpy.arange(90, 320, step=30))

plt.yticks(numpy.arange(-15, -3, step=2))

plt.legend(['ODIXEG', 'HAFTOZ', 'XEBHOC', 'LURGEL', 'XAWVUN', 'ANUGIA', 'JEJWOL', 'BICDAU', 'HIGRIA', 'NEDWIE'], bbox_to_anchor = (1.0, 1.05), fontsize=14 )

# %%
list = [Topt_150K, Topt_regression, Topt_actual] 


for i in list:
    
            plt.scatter(CCDC_ref_code, i)

plt.xlabel("CCDC ref code", fontsize=16)

plt.ylabel('Temperature (K)', fontsize=16)

plt.xticks(fontsize=14, rotation=90) 

plt.yticks(fontsize=14)

plt.yticks(numpy.arange(120, 160, step=5))

plt.legend([r'$\T_{opt}_$\Delta H_{O_{2}} $@150 K (K)', r'$\T_{opt}_Regression (K)', 'Topt_Actual (K)'], bbox_to_anchor = (1.0, 1.4), fontsize=14 )

# %%
import numpy as np
import os, glob

parent_dir = '/storage/home/hcoda1/5/sjamdade3/p-dsholl3-0/RASPA2-master/examples/Non-Basic/O2_He/FINAL/Top_10_Isotherm'

directory_contents = os.listdir(parent_dir)
for item in directory_contents:
    if os.path.isdir(item):
        path_MOF = os.path.join(parent_dir, str(item))
        Pressures = [1,  2,  3, 4, 5, 6, 7]
        print(path_MOF)
        for value in Pressures:

            path_data = os.path.join(path_MOF, str(value), 'Output', 'System_0')
            os.chdir(path_data)
            for file in glob.glob("*.data"):
                X = None
                T = None
                P = None

                Enthalpy_adsorption = []
                std_E_H = []

                absolute_gravimetric_uptake_avg = []
                std_gravimetric = []

                absolute_volumetric_uptake_avg = []
                std_volumetric = []

                E_H_total = None
                E_H_O2 = None
                E_H_He = None
                E_H_mix = None

                STD_E_H_total = None
                STD_E_H_O2 = None
                STD_E_H_He = None
                STD_E_H_mix = None

                Gravimetric_Uptake_He = None
                Gravimetric_Uptake_O2 = None
                Volumetric_Uptake_He = None
                Volumetric_Uptake_O2 = None

                STD_G_U_He = None
                STD_G_U_O2 = None
                STD_V_U_He = None
                STD_V_U_O2 = None

                f = open(file,'r')
                lines=f.readlines()
                f.close()

                for line in lines:
                    row=line.split()

                    if not line.strip():
                         continue

                    if len(row)==3 and row[0] == 'MolFraction:':
                        X = float(row[1])

                    if len(row)==4 and row[0] == 'External' and row[1] == 'temperature:' and row[3] == '[K]':
                        T = float(row[2])

                    if len(row)==4 and row[0] == 'Partial' and row[1] == 'pressure:' and row[3] == '[Pa]':
                        P = float(row[2])

                    if len(row)==4 and row[1] == '+/-' and row[3] == '[KJ/MOL]':
                        Enthalpy_adsorption.append(float(row[0]))
                        std_E_H.append(float(row[2]))

                    if len(row)==9 and row[0] == 'Average' and row[1] == 'loading' and row[2] == 'absolute' and row[3] == '[mol/kg':
                        absolute_gravimetric_uptake_avg.append(float(row[5]))
                        std_gravimetric.append(float(row[7]))


                    if len(row)==10 and row[0] == 'Average' and row[1] == 'loading' and row[2] == 'absolute' and row[3] == '[cm^3'and row[4] == '(STP)/cm^3':
                        absolute_volumetric_uptake_avg.append(float(row[6]))
                        std_volumetric.append(float(row[8]))


                E_H_total = Enthalpy_adsorption[0]
                STD_E_H_total = std_E_H[0]
                E_H_O2 = Enthalpy_adsorption[2]
                STD_E_H_O2 = std_E_H[2]
                E_H_He = Enthalpy_adsorption[1]
                STD_E_H_He = std_E_H[1]
                E_H_mix = Enthalpy_adsorption[3]
                STD_E_H_mix = std_E_H[3]

                Gravimetric_Uptake_He = absolute_gravimetric_uptake_avg[0]
                STD_G_U_He = std_gravimetric[0]

                Gravimetric_Uptake_O2 = absolute_gravimetric_uptake_avg[1]
                STD_G_U_O2 = std_gravimetric[1]

                Volumetric_Uptake_He = absolute_volumetric_uptake_avg[0]
                STD_V_U_He = std_volumetric[0]

                Volumetric_Uptake_O2 = absolute_volumetric_uptake_avg[1]
                STD_V_U_O2 = std_volumetric[1]


                final_line = ' MOF_NO.'+str(i)+' Pressure '+str(P)+' Temperature '+str(T)+' Mole_fraction '+str(X)+' Delta_H_Total '+str(E_H_total)+' STD_EH_total '+str(STD_E_H_total)+' Delta_H_He '+str(E_H_He)+' STD_EH_He '+str(STD_E_H_He)+' Delta_H_O2 '+str(E_H_O2)+' STD_EH_O2 '+str(STD_E_H_O2)+' Delta_H_mix '+str(E_H_mix)+' STD_EH_mix '+str(STD_E_H_mix)+' Gravimetric_uptake_He '+str(Gravimetric_Uptake_He)+' STD_GU_He '+str(STD_G_U_He)+' Gravimetric_uptake_O2 '+str(Gravimetric_Uptake_O2)+' STD_GU_O2 '+str(STD_G_U_O2)+' Volumetric_uptake_He '+str(Volumetric_Uptake_He)+' STD_VU_He '+str(STD_V_U_He)+' Volumetric_uptake_O2 '+str(Volumetric_Uptake_O2)+' STD_VU_O2 '+str(STD_V_U_O2) 

                with open(str(parent_dir) + '/Appropriate_GCMC_Data.txt', 'a') as file_final:

                        file_final.write(str(final_line))
                        file_final.write("\n")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/yv/px_046ms6wxf2jkb1sgl2c040000gn/T/ipykernel_6099/3972792441.py in <module>
#       4 parent_dir = '/storage/home/hcoda1/5/sjamdade3/p-dsholl3-0/RASPA2-master/examples/Non-Basic/O2_He/FINAL/Top_10_Isotherm'
#       5
# ----> 6 directory_contents = os.listdir(parent_dir)
#       7 for item in directory_contents:
#       8     if os.path.isdir(item):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/storage/home/hcoda1/5/sjamdade3/p-dsholl3-0/RASPA2-master/examples/Non-Basic/O2_He/FINAL/Top_10_Isotherm'
